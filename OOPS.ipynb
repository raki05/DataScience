# %% [markdown]
# **1.What is Object-Oriented Programming (OOP)?**
#   Object oriented programming is coding structure where you design your code around object rather than just function or logic.It makes code reusable and easier to maintain by modeling it to real world problem.
#
# **2.What is a class in OOP?**
#   Class in oop is blueprint or template using which objects are create. It basically offers 2 things:
#     data-> variable that belongs to the object
#     behavior-> function that applies on the data.
#
# **3.What is an object in OOP?**
#   Object in oop is instance of a class.It's a real usable things created from class blueprint.
#
# **4.  What is the difference between abstraction and encapsulation?**
#   Abstraction is hiding internal implementation and only exposing esential feature to the outside world.
#   Encapsulation is binding internal data and method to a signle class and restricting access to some data by making it private.
#
# **5.What are dunder methods in Python?**
#   Dunder method in python are inbuild class method.These are special method whose name starts and edns with two underscore. They are also known as special or magic methods. Ex: __add__ ,__str__
#
# **6.Explain the concept of inheritance in OOP?**
#   Inheritance is an oops concept where a class can extend proprty and method of another class and by doing so it inherits all it's data and behaviour. Inheritance creates code reusability and avoid duplications.
#
# **7.What is polymorphism in OOP?**
#   Ability of differenct classes to call same methods in different ways is call polymorphism. The same method can call or behave differently depending on the object which is calling it.
#
# **8.How is encapsulation achieved in Python?**
#   Encapsulation is achieved by making data and method as private within a class. You can make data and method as private by putting 2 underscores at start of variable name or method.
#
# **9.What is a constructor in Python?**
#   Constructor in python are used to initialize a class or create an object. It also assign memory to an object.
#
# **10.What are class and static methods in Python?**
#   Class methods are bound to the class and not object.It recieves class itself as an argument. Class method are used to access and modify class variable.
#   Static methods are assigned to class but doesn't take class or instance as argument. Static method doesn't modify class variabls.
#
# **11.What is method overloading in Python?**
#   Method overloading is having same method name but accept different paramters within a class. Python doesn't support method overloading typically as it will always load latest method defined within class while creating an instance or throw error.
#
# **12.What is method overriding in OOP?**
#   Method overriding is when child class provides different implementation for a method which is also present in parent class.
#
# **13.What is a property decorator in Python?**
#   The @property decorator in python are used to make a method behave like and attribute.
#
# **14.Why is polymorphism important in OOP?**
#   Polymorphism in python make code resusable, flexible and easier to maintain by allowing the same method to be called by different type of object.
#
# **15.What is an abstract class in Python?**
#   Abstract class in pthon are classes which can't be instantitated and act as a blueprint for other classes. An abstract class should have atleast one abstract method which would be implemented by it's child class.
#
# **16.What are the advantages of OOP?**
#   OOP make code reusable,flexible and easier to maintain by offering charectristics like inheritance,polymorphism,encapsulation and abstratction.
#
# **17.What is the difference between a class variable and an instance variable?**
#   Class variable are defined at class level outside of any method it belongs to the class and shared by all instances of class.
#   Instance variable belongs to an object and diffiend inside a method , each object gets it's own copy of instance variable.
#
# **18.What is multiple inheritance in Python?**
#   Multiple inheritence in python is when a child class inherrit from multiple parents.
#     ex: class Father:
#            pass
#         class Mother:
#             pass
#         class Child(Father,Mother):
#             pass
# **19.Explain the purpose of "__str__" and "__repr__"  methods in Python?**
#   __str__ and __repr__ are dundor methods they are used to return user friendly or devloper friendly message respectively.__str__ are used for readiblity presepectiv for end users. Whereas __repr__ is used by devloper in case of debugging.
#
# **20.What is the significance of the ‘super()’ function in Python?**
#   super() function in python is used to call a method from paternt calss by child class withoud specifically using class name.
#
# **21.What is the significance of the __del__ method in Python?**
#   The __del__ method in python is a dunder or special method that is called when object is about to being destroyed. It is used in garbage collection.
#
# **22.What is the difference between @staticmethod and @classmethod in Python?**
#   StaticMethod is assigned to a class but doesn't take cls or instance as an argument. It can't modify class variables.
#   ClassMethod belongs to class it takes cls as an argument and are used to modify class variabl.
#
# **23.How does polymorphism work in Python with inheritance?**
#   Polymorphism in python works with inheritance by allowing same method name under different child class of a parent class and at runtime it decide which version of method implementation will be called.
#
# **24.What is method chaining in Python OOP?**
#   Method chaining in python is a concept where you call different methods of same object in a single line , as each method of an object returns 'self' object, using which you will call another method.
#
# **25. What is the purpose of the __call__ method in Python?**
#   __call__ is dunder or magic method in python which makes an object callable entities.
#   Ex: class Greet:
#           def __init__(self,greeting):
#                 self.greeting = greeting
#           def __call__(self,name):
#               self.name = name
#               return f"{self.greeting}, {self.name}"
#       greet = Greet("Hello")
#       print(greet("rakesh"))
#       print(greet("ramesh"))

# %%
'''1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".'''

class Animal:
  def speak(self):
    print("Animal is speaking")
class Dog(Animal):
  def speak(self):
    print("Bark!")
d = Dog()
d.speak()
# Out:
# Bark!

# %%
'''2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.'''

from abc import ABC,abstractmethod
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass
class Circle(Shape):
  def __init__(self,radius):
    self.radius = radius
  def area(self):
    return 3.14*(self.radius**2)
class Rectangle(Shape):
  def __init__(self,base,height):
    self.base = base
    self.height = height
  def area(self):
    return self.base*self.height

c = Circle(4)
print(f"Area of circle is {c.area()}")
r = Rectangle(3,4)
print(f"Area of rectangle is {r.area()}")
# Out:
# Area of circle is 50.24
# Area of rectangle is 12

# %%
'''3.Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.'''

class Vehicle:
  def __init__(self,type):
    self.type = type
class Car(Vehicle):
  def __init__(self,type):
    super().__init__(type)
class ElectricCar(Car):
  def __init__(self,type,battery):
    super().__init__(type)
    self.battery = battery
    print(f"{self.type},{self.battery}")
ec = ElectricCar("4 wheeler","Lithim300")
# Out:
# 4 wheeler,Lithim300

# %%
'''4.Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method'''

class Bird:
  def fly(self):
    print("Bird flying")
class Sparrow(Bird):
  def fly(self):
    print("Sparrow flying")
class Penguin(Bird):
  def fly(self):
    print("penguin can't fly")

s = Sparrow()
p = Penguin()
s.fly()
p.fly()
# Out:
# Sparrow flying
# penguin can't fly

# %%
'''5.Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.'''

class BankAccount:
  def __init__(self,balance=0):
    self.__balance = balance
  def deposit(self,amount):
    if amount > 0:
      self.__balance += amount
      print(f"Amount deposited: {amount}")
    else:
      print("amount should be positive")

  def withdraw(self,amount):
    if 0 < amount <= self.__balance:
      self.__balance -= amount
      print(f"Amounth withdrwan: {amount}")
    else:
      print("Invalid amount or insufficient ballance")
  def checkBalance(self):
    print(f"Current balance is: {self.__balance}")
ba = BankAccount(1000)
ba.deposit(300)
ba.withdraw(1500)
ba.checkBalance()
# Out:
# Amount deposited: 300
# Invalid amount or insufficient ballance
# Current balance is: 1300

# %%
'''6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play()'''
class Instrument:
  def play(self):
    print("Paly instruement")
class Guitar(Instrument):
  def play(self):
    print("play guitar")
class Piano(Instrument):
  def play(self):
    print("play piano")

g = Guitar()
p = Piano()
g.play()
p.play()
# Out:
# play guitar
# play piano

# %%
'''7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers?'''
class MathOperations:
  @classmethod
  def add_numbers(cls,a,b):
    cls.a = a
    cls.b =b
    return cls.a + cls.b
  @staticmethod
  def subtract_numbers(a,b):
    return a-b
print(f"Class Method returns :{MathOperations.add_numbers(3,4)}")
print(f"Static method returns: {MathOperations.subtract_numbers(4,3)}")
# Out:
# Class Method returns :7
# Static method returns: 1

# %%
'''8. Implement a class Person with a class method to count the total number of persons created.'''
class Person:
  count = 18
  @classmethod
  def countPerson(cls):
    print(f"Total number of person cerated is: {cls.count}")
Person.countPerson()
# Out:
# Total number of person cerated is: 18

# %%
'''9.Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator'''
class Fraction:
  def __init__(self,numerator,denominator=1):
       self.numerator = numerator
       self.denominator = denominator

  def __str__(self):
    return f"{self.numerator}/{self.denominator}"

f = Fraction(6,3)
print(f)
# Out:
# 6/3

# %%
'''10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.'''
class Vector:
  def __init__(self,a,b):
    self.a = a
    self.b = b
  def __add__(self,other):
    return Vector(self.a + other.a, self.b + other.b)
  def __str__(self):
    return f"{self.a},{self.b}"
v1 = Vector(3,4)
v2 = Vector(5,6)
v3 =  v1 + v2
print(v3)
# Out:
# 8,10

# %%
'''11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."'''

class Person:
  def __init__(self,name,age):
    self.name =  name
    self.age = age
  def greet(self):
    return f"'Hello, my name is {self.name} and i am {self.age} yeas.old'"
p = Person("Rakesh",30)
p.greet()
# Out:
# "'Hello, my name is Rakesh and i am 30 yeas.old'"

# %%
'''12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades.'''

class Student:
  def __init__(self,name,grades):
    self.name = name
    self.grades = grades
  def average_grade(self):
    sum = 0
    for grade in self.grades:
      sum = sum + grade
    return sum/len(self.grades)

s1 = Student("Rakesh",[35,60,70,95])
s1.average_grade()
# Out:
# 65.0

# %%
'''13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.'''

class Rectangle:
  def __init__(self):
    self.length = 0
    self.width = 0
  def set_dimensions(self,length,width):
    self.length = length
    self.width = width
  def area(self):
    return self.length*self.width

r = Rectangle()
r.set_dimensions(4,3)
r.area()
# Out:
# 12

# %%
'''14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary.'''

class Employee:
  def __init__(self,hoursworked,hourlyrate):
    self.hoursworked = hoursworked
    self.hourlyrate =  hourlyrate
  def calculate_salary(self):
    return self.hoursworked*self.hourlyrate
class Manager(Employee):
  def __init__(self,hoursworked,hourlyrate,bonus):
    super().__init__(hoursworked,hourlyrate)
    self.bonus = bonus
  def calculate_salary(self):
    return super().calculate_salary() + self.bonus
m = Manager(8,1000,300)
m.calculate_salary()
# Out:
# 8300

# %%
'''15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.'''

class Product:
  def __init__(self,name,price,quantity):
    self.name = name
    self.price = price
    self.quantity = quantity
    print(f"Total price of product {name} is: {price*quantity}")

p = Product("watches",15000, 10)
# Out:
# Total price of product watches is: 150000

# %%
'''16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.'''
from abc import ABC,abstractmethod

class Animal(ABC):
  @abstractmethod
  def sound(self):
    pass
class Cow(Animal):
  def sound(self):
    print(f"Cow does moo moo")
class Sheep(Animal):
  def sound(self):
    print(f"Sheep does ba ba")
c = Cow()
s = Sheep()
c.sound()
s.sound()
# Out:
# Cow does moo moo
# Sheep does ba ba

# %%
'''17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.'''

class Book:
  def __init__(self,title,author,year_published):
    self.title = title
    self.author = author
    self.year_published = year_published

  def get_book_info(self):
    return f"Book Details:{self.title},{self.author},{self.year_published}"

b = Book("Let us C","Yaswant kanitkar",2008)
b.get_book_info()
# Out:
# 'Book Details:Let us C,Yaswant kanitkar,2008'

# %%
'''18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.'''

class House:
  def __init__(self,address,price):
    self.address = address
    self.price = price

class Mansion(House):
  def __init__(self,address,price,number_of_rooms):
    super().__init__(address,price)
    self.number_of_rooms = number_of_rooms

    print(f"The mansion address is:{self.address},price is: {self.price} and number of rooms are: {self.number_of_rooms}")

m = Mansion("Sarjapur", 2000000000.00, 8)
# Out:
# The mansion address is:Sarjapur,price is: 2000000000.0 and number of rooms are: 8

# %% [markdown]
# **1.What is the difference between interpreted and compiled languages?**
#   In inteprted language code is read and executed line by line at runtime.
#   In compiled language code is first converted in to machine language by compiler and then directly run in to run time enviornment of computer.
#   Typically compile type language are faster in executions.
#
# **2.What is exception handling in Python?**
#   Handling any unwanted even during flow of execution is called exception handling. Exception handling ensures that any unwanted event doesnt interrupt the flow of execution and it's been handled properly so that a program can execute successfully.
#
# **3.What is the purpose of the finally block in exception handling?**
#   The code writtend under finally block will always execute whether there is exception or not. It's useful when we would like to close any open network or database connection, such closer we alway do under finally block.
#
# **4.What is logging in Python?**
#   Logging is a way of tracking and recording flow of execution of program. It is used for monitoring , debugging and troubleshooting puprose.
#
# **5.What is the significance of the __del__ method in Python?**
#   __del__ method in python is a dunder method which is always called when an object is about to be destroyed. They are used during garbage colleciton.
#
# **6.What is the difference between import and from ... import in Python?**
#    Import is used when we are directly importing a module within our code whereas from... import are used when we try to import something from libarary or a package.
#
# **7. How can you handle multiple exceptions in Python?**
#   We can handle multiple exception in python by using multiple except block or using , seperated exceptions list using single except block. If we have multiple exception we can directly give generic exception under single except block and hadle it through that as well.
#
# **8.What is the purpose of the with statement when handling files in Python?**
#   When we use 'with' statement to handle file esentially we dont have to bother about closing the file once read or write operation is done.
#
# **9. What is the difference between multithreading and multiprocessing?**
#  Multitheading is running multiple thread of a program concurrently in single processor.
#  Multiprocessing is running application under multiple processors parallely.
#  Multithreading is good for I/O bound program where as Multiprocessing is used for CPU oriented applicaitons.
#
# **10.What are the advantages of using logging in a program?**
#    Logging is a way of tracking and recording flow of execution of program. It is used for monitoring , debugging and troubleshooting puprose.
#
# **11.What is memory management in Python?**
#    Memory Managment in python is automatic process where python takes care of memory management using private heap,reference counter and garbage collection.As an developer we should write memomry efficient program with proper time and space complexity so that memory management can be done faster and effective manner by pyton.
#
# **12.What are the basic steps involved in exception handling in Python?**
#    We should write the buggy/suspected code under try block and handle any potential exception under except block. Optionally we can also use finally and else blocks for keeping codes which require explicity closure statement and codes which require happy paths to be put under seperate block respectively.
#
# **13.Why is memory management important in Python?**
#   Memory management in python is important because it impact performance, stablility and scalability of program.
#
# **14.What is the role of try and except in exception handling?**
#   We write code that may raise exception under try block. Under except block we handle exception raised under try block for successful execution of program without and disruption.
#
# **15.How does Python's garbage collection system work?**
#   Garbage collection automatically reclaim the memory used by objects that are no longer in use. In some scenario you can invoke garbage collection in your code to enforce garbage collection manually.
#
# **16.What is the purpose of the else block in exception handling?**
#   The else block in python exception handling is used when you have a code that should only run if there is no exception recoreded in try block.
#
# **17.What are the common logging levels in Python?**
#   There are 5 common logging levals in python they are DEBUG,INFO,TRACE,ERROR and CRITICAl. You can set the logging level using baseconfig in python.
#
# **18.What is the difference between os.fork() and multiprocessing in Python?**
#   os.fork() or multiprocessing modeule both create new processes in python but they differ in interoperability as os.fork() can only work on linux/unix platform whereas multiprocessing moudule had wide coverage and it's crossplatform supported.There use cases are also different os.fork() is used for low level programming like system level process control whre as multiprocessing is used on high level applicaitons like python programs to create parallelism.
#
# **19.What is the importance of closing a file in Python?**
#   When you close a file it ensures that system resources are released and data is saved. When we run close function it ensures that buffer is flushed and data is saved at the disk.
#
# **20.What is the difference between file.read() and file.readline() in Python?**
#   file.read() read entire files into a single string whereas file.readline() just read single line of a file till we reach /n.
#
# **21.What is the logging module in Python used for?**
#   Logging module is used for tracking events while programe is running. It's python built in way to handle debugging,monitoring and auditing wihtout using print statement.
#
# **22.What is the os module in Python used for in file handling?**
#   Python uses 'open' and 'with open' module for file handling.
#
# **23.What are the challenges associated with memory management in Python?**
#   Though python handle memory management automatically but the way we write the code pose severall challanges during memory management like Memory Leaks,Circular Reference, High Memory usage and Garbage collection overhead.
#
# **24.How do you raise an exception manually in Python?**
#   We can create a custom class for exception handling which implement Exception class. By using this we can pass custom exception manually at run time. We can also raise manual exception using built in function raise.
#
# **25. Why is it important to use multithreading in certain applications?**
#    It is important to use multihtreading in certain applications because it will make program faster and responsive without using multiple process. If we have I/O bound applicaiton we can use multipthreading to create multiple thread of a program which can run concurrently within a single process to make program execution faster.

# %%
'''1.How can you open a file for writing in Python and write a string to it.'''

file =  open("demo.txt", "w")
file.write("Hello World")
file.close()

# %%
'''2.Write a Python program to read the contents of a file and print each line.'''
with open("/content/sample_data/README.md", "r") as f:
  content = f.read()
  print(content)
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).

# %%
'''3.How would you handle a case where the file doesn't exist while trying to open it for reading'''
try:
  file = open("file.txt" ,"r")
  file.read()
except Exception as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'file.txt'

# %%
'''4.Write a Python script that reads from one file and writes its content to another file?'''

with open("/content/sample_data/README.md", "r") as f:
  content = f.read()

with open("file.txt" , "w") as f:
  f.write(content)

print("source file content successfully copied to destination file.")
# Out:
# source file content successfully copied to destination file.

# %%
'''5.How would you catch and handle division by zero error in Python?'''

try:
  5/0
except ZeroDivisionError:
  print(f"Error: zero division error occured")
# Out:
# Error: zero division error occured

# %%
'''6.Write a Python program that logs an error message to a log file when a division by zero exception occurs?'''
import logging
logging.basicConfig(filename = "error.log" , level = logging.ERROR, format= "%(asctime)s - %(levelname)s - %(message)s", force = True)

try:
  5/0
except ZeroDivisionError:
  logging.error(f"Zero Division error has occured!!")

print(f"Program finished check the error in error.log !!")
# Out:
# Program finished check the error in error.log !!

# %%
'''7.How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?'''

import logging
logging.basicConfig(level = logging.DEBUG, format= "%(asctime)s - %(levelname)s - %(message)s", force = True )

logging.info(f"This is information message")
logging.warning(f"This is warning message")
logging.error(f"This is error message")
# Out:
# 2025-08-13 11:34:37,954 - INFO - This is information message
# 2025-08-13 11:34:37,955 - WARNING - This is warning message
# 2025-08-13 11:34:37,956 - ERROR - This is error message

# %%
'''8.Write a program to handle a file opening error using exception handling'''

try:
  file = open("sample.txt", "r")
  file.read()
except FileNotFoundError as e:
  print(f"Unable to open a file and failed with error :  {e}")
# Out:
# Unable to open a file and failed with error :  [Errno 2] No such file or directory: 'sample.txt'

# %%
'''9.How can you read a file line by line and store its content in a list in Python'''

with open("/content/sample_data/README.md" , "r") as f:
  contents = f.readlines()

lines = [content.strip() for content in contents]
print(lines)
# Out:
# ['This directory includes a few sample datasets to get you started.', '', '*   `california_housing_data*.csv` is California housing data from the 1990 US', 'Census; more information is available at:', 'https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub', '', '*   `mnist_*.csv` is a small sample of the', '[MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is', 'described at: http://yann.lecun.com/exdb/mnist/', '', '*   `anscombe.json` contains a copy of', "[Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it", 'was originally described in', '', "Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American", 'Statistician. 27 (1): 17-21. JSTOR 2682899.', '', 'and our copy was prepared by the', '[vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).']

# %%
'''10. How can you append data to an existing file in Python?'''

with open("file.txt" , "a") as f:
  f.write("new line")

print(f" file.txt has appeneded with new line")
# Out:
#  file.txt has appeneded with new line

# %%
'''11 Write a Python program that uses a try-except block to handle an error when attempting to access a
dictionary key that doesn't exist'''

d = {"x" : 1, "y" : 2 , "z" : 3}
try:
  d['a']
except KeyError as e:
  print(f"The value in dictonary d is not found for key :  {e}")
# Out:
# The value in dictonary d is not found for key :  'a'

# %%
'''12.Write a program that demonstrates using multiple except blocks to handle different types of exceptions?'''

num1 = int(input("Enter num1: "))
num2 = int(input("Enter num2: "))

d = {"x" : 1, "y" : 2 , "z" : 3}
try:

 result = num1/num2
 key = input("Enter a key: ")
 d[key]

 with open("sample.txt", "r") as f:
    f.read()

except ZeroDivisionError:
  print(f"Zero division error has occured")
except KeyError:
  print(f"Key error occured as searched {key} not found in dictonary")
except FileNotFoundError:
  print(f"File not found error.")
# Out:
# Enter num1: 4
# Enter num2: 5
# Enter a key: y
# File not found error.

# %%
'''13 How would you check if a file exists before attempting to read it in Python?'''
import os
file_path = "file.txt"
if os.path.exists(file_path):
   with open(file_path, "r") as f:
        content = f.read()
   print(content)
else:
  print("File does not exist.")
# Out:
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://docs.google.com/document/d/e/2PACX-1vRhYtsvc5eOR2FWNCwaBiKL6suIOrxJig8LcSBbmCbyYsayia_DvPOOBlXZ4CAlQ5nlDD8kTaIDRwrN/pub
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).
# ...

# %%
'''14. Write a program that uses the logging module to log both informational and error messages?'''

import logging
logging.basicConfig(level= logging.INFO , format= "%(asctime)s - %(levelname)s - %(message)s", force = True)

logging.info(f"This is informational message")
logging.error(f"This is error message")
# Out:
# 2025-08-13 12:08:34,050 - INFO - This is informational message
# 2025-08-13 12:08:34,051 - ERROR - This is error message

# %%
'''15.Write a Python program that prints the content of a file and handles the case when the file is empty'''

with open("error.log", "r") as f:
  content = f.read()

if not content:
  print(f"file is empty")
else:
  print(content)
# Out:
# 2025-08-13 11:26:39,210 - ERROR - Zero Division error has occured!!

# %%
'''16.Demonstrate how to use memory profiling to check the memory usage of a small program?'''
# !pip install memory_profiler

# %load_ext memory_profiler

from memory_profiler import profile

@profile
def my_function():
    x = [1] * 1000000
    y = [2] * 2000000
    del x
    return y

my_function()
# Out:
# ...
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler
# ERROR: Could not find file /tmp/ipython-input-1023761624.py
# [2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
#  2,
# ...

# %%
# %mprun -f my_function my_function()
# Out:
# ERROR: Could not find file /tmp/ipython-input-1023761624.py

# %%
'''17.Write a Python program to create and write a list of numbers to a file, one number per line?'''

l1 = [1,2,3,4]

with open("sample.txt" , "a+") as f:
  for item in l1:
    f.write(str(item) + "\n")

# %%
'''18. How would you implement a basic logging setup that logs to a file with rotation after 1MB'''

import logging
from logging.handlers import RotatingFileHandler

logger = logging.getLogger("my_logger")
logger.setLevel(logging.INFO)
handler = RotatingFileHandler(
    "app.log",
    maxBytes=1_000_000
)

formatter = logging.Formatter(
    '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)
handler.setFormatter(formatter)

logger.addHandler(handler)

logger.info("This is an info message")
logger.error("This is an error message")
# Out:
# 2025-08-13 12:36:03,002 - INFO - This is an info message
# 2025-08-13 12:36:03,004 - ERROR - This is an error message

# %%
'''19.Write a program that handles both IndexError and KeyError using a try-except block'''

my_list = [10, 20, 30]
my_dict = {"a": 1, "b": 2}

try:

    print("Accessing list:", my_list[5])

    print("Accessing dict:", my_dict["c"])

except IndexError as ie:
    print(f"IndexError caught: {ie}")

except KeyError as ke:
    print(f"KeyError caught: {ke}")

print("Program continues")
# Out:
# IndexError caught: list index out of range
# Program continues

# %%
'''20.How would you open a file and read its contents using a context manager in Python?'''


file_path = "sample.txt"

with open(file_path, "r") as file:
    contents = file.read()

print("File contents:")
print(contents)
# Out:
# File contents:
# 1
# 2
# 3
# 4
# 1
# 2
# 3
# 4

# %%
 '''21.Write a Python program that reads a file and prints the number of occurrences of a specific word'''
import re
file_path = "example.txt"

word_to_count = "Python"



count = 0

with open(file_path, "r") as file:
    for line in file:
        words = re.findall(r'\b\w+\b', line.lower())
        count += words.count(word_to_count.lower())

print(f"The word '{word_to_count}' occurs {count} times in the file.")
# Out:
# The word 'Python' occurs 3 times in the file.

# %%
'''22.How can you check if a file is empty before attempting to read its contents'''

with open("sample.txt" , "r") as f:
  content =  f.read()

if not content:
  print("file is empty")
else:
  print(content)
# Out:
# 1
# 2
# 3
# 4
# 1
# 2
# 3
# 4

# %%
'''23.Write a Python program that writes to a log file when an error occurs during file handling'''

import logging


logging.basicConfig( filename="file_errors.log",level=logging.ERROR,format="%(asctime)s - %(levelname)s - %(message)s" ,force= True)

file_path = "demo-new.txt"

try:
    with open(file_path, "r") as f:
        content = f.read()
        print("File content:")
        print(content)

except FileNotFoundError as e:
    logging.error(f"File not found: {e}")
